# %% [markdown]
# # Creating a Personalized Maplist Scraper for Splatoon3

# %%
import os 
import pandas as pd
import numpy as np
from lxml import html
from lxml import etree
import requests
from bs4 import BeautifulSoup
import re
import datetime

# %%
page_url = "https://splatoon3.ink/data/schedules.json"
start_time = []
end_time = []
mode_list = []
map_list = []
text = requests.get(page_url).text
text

import json
data = json.loads(text)

data
# Out:
# {'data': {'regularSchedules': {'nodes': [{'startTime': '2023-10-19T18:00:00Z',
#      'endTime': '2023-10-19T20:00:00Z',
#      'regularMatchSetting': {'__isVsSetting': 'RegularMatchSetting',
#       '__typename': 'RegularMatchSetting',
#       'vsStages': [{'vsStageId': 12,
#         'name': 'Mahi-Mahi Resort',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/8273118c1ffe1bf6fe031c7d8c9795dab52632c9b76e8e9f01f644ac5ae0ccc0_1.png'},
#         'id': 'VnNTdGFnZS0xMg=='},
#        {'vsStageId': 15,
#         'name': 'MakoMart',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/a8ba96c3dbd015b7bc6ea4fa067245c4e9aee62b6696cb41e02d35139dd21fe7_1.png'},
#         'id': 'VnNTdGFnZS0xNQ=='}],
#       'vsRule': {'name': 'Turf War',
#        'rule': 'TURF_WAR',
#        'id': 'VnNSdWxlLTA='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-19T20:00:00Z',
#      'endTime': '2023-10-19T22:00:00Z',
#      'regularMatchSetting': {'__isVsSetting': 'RegularMatchSetting',
#       '__typename': 'RegularMatchSetting',
#       'vsStages': [{'vsStageId': 9,
#         'name': 'Flounder Heights',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/488017f3ce712fca9fb37d61fe306343054449bb2d2bb1751d95f54a98564cae_1.png'},
#         'id': 'VnNTdGFnZS05'},
#        {'vsStageId': 11,
#         'name': "Museum d'Alfonsino",
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/b9d8cfa186d197a27e075600a107c99d9e21646d116730f0843e0fff0aaba7dd_1.png'},
#         'id': 'VnNTdGFnZS0xMQ=='}],
#       'vsRule': {'name': 'Turf War',
#        'rule': 'TURF_WAR',
#        'id': 'VnNSdWxlLTA='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-19T22:00:00Z',
#      'endTime': '2023-10-20T00:00:00Z',
#      'regularMatchSetting': {'__isVsSetting': 'RegularMatchSetting',
#       '__typename': 'RegularMatchSetting',
#       'vsStages': [{'vsStageId': 12,
#         'name': 'Mahi-Mahi Resort',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/8273118c1ffe1bf6fe031c7d8c9795dab52632c9b76e8e9f01f644ac5ae0ccc0_1.png'},
#         'id': 'VnNTdGFnZS0xMg=='},
#        {'vsStageId': 16,
#         'name': 'Wahoo World',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/61ea801fa4ed32360dcaf83986222ded46a72dbf56194acc6d0cf4659a92ba85_1.png'},
#         'id': 'VnNTdGFnZS0xNg=='}],
#       'vsRule': {'name': 'Turf War',
#        'rule': 'TURF_WAR',
#        'id': 'VnNSdWxlLTA='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T00:00:00Z',
#      'endTime': '2023-10-20T02:00:00Z',
#      'regularMatchSetting': {'__isVsSetting': 'RegularMatchSetting',
#       '__typename': 'RegularMatchSetting',
#       'vsStages': [{'vsStageId': 2,
#         'name': 'Eeltail Alley',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/898e1ae6c737a9d44552c7c81f9b710676492681525c514eadc68a6780aa52af_1.png'},
#         'id': 'VnNTdGFnZS0y'},
#        {'vsStageId': 10,
#         'name': 'Hammerhead Bridge',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/1db8ab338b64b464df50e7f9e270e59423ff8caac6f09679a24f1b7acf3a82f3_1.png'},
#         'id': 'VnNTdGFnZS0xMA=='}],
#       'vsRule': {'name': 'Turf War',
#        'rule': 'TURF_WAR',
#        'id': 'VnNSdWxlLTA='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T02:00:00Z',
#      'endTime': '2023-10-20T04:00:00Z',
#      'regularMatchSetting': {'__isVsSetting': 'RegularMatchSetting',
#       '__typename': 'RegularMatchSetting',
#       'vsStages': [{'vsStageId': 1,
#         'name': 'Scorch Gorge',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/35f9ca08ccc2bf759774ab2cb886567c117b9287875ca92fb590c1294ddcdc1e_1.png'},
#         'id': 'VnNTdGFnZS0x'},
#        {'vsStageId': 8,
#         'name': 'Barnacle & Dime',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/f70e9f5af477a39ccfab631bfb81c9e2cedb4cd0947fe260847c214a6d23695f_1.png'},
#         'id': 'VnNTdGFnZS04'}],
#       'vsRule': {'name': 'Turf War',
#        'rule': 'TURF_WAR',
#        'id': 'VnNSdWxlLTA='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T04:00:00Z',
#      'endTime': '2023-10-20T06:00:00Z',
#      'regularMatchSetting': {'__isVsSetting': 'RegularMatchSetting',
#       '__typename': 'RegularMatchSetting',
#       'vsStages': [{'vsStageId': 3,
#         'name': 'Hagglefish Market',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/8dc2f16d39c630bab40cead5b2485ca3559e829d0d3de0c2232c7a62fefb5fa9_1.png'},
#         'id': 'VnNTdGFnZS0z'},
#        {'vsStageId': 6,
#         'name': 'Mincemeat Metalworks',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/de1f212e9ff0648f36cd3b8e0917ef36b3bd51445159297dcb948f34a09f2f05_1.png'},
#         'id': 'VnNTdGFnZS02'}],
#       'vsRule': {'name': 'Turf War',
#        'rule': 'TURF_WAR',
#        'id': 'VnNSdWxlLTA='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T06:00:00Z',
#      'endTime': '2023-10-20T08:00:00Z',
#      'regularMatchSetting': {'__isVsSetting': 'RegularMatchSetting',
#       '__typename': 'RegularMatchSetting',
#       'vsStages': [{'vsStageId': 4,
#         'name': 'Undertow Spillway',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/9b1c17b2075479d0397d2fb96efbc6fa3a28900712920e5fe1e9dfc59c6abc5c_1.png'},
#         'id': 'VnNTdGFnZS00'},
#        {'vsStageId': 16,
#         'name': 'Wahoo World',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/61ea801fa4ed32360dcaf83986222ded46a72dbf56194acc6d0cf4659a92ba85_1.png'},
#         'id': 'VnNTdGFnZS0xNg=='}],
#       'vsRule': {'name': 'Turf War',
#        'rule': 'TURF_WAR',
#        'id': 'VnNSdWxlLTA='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T08:00:00Z',
#      'endTime': '2023-10-20T10:00:00Z',
#      'regularMatchSetting': {'__isVsSetting': 'RegularMatchSetting',
#       '__typename': 'RegularMatchSetting',
#       'vsStages': [{'vsStageId': 5,
#         'name': "Um'ami Ruins",
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/f14c2a64e49d243679fc0884af91e1a07dc65600f9b90aefe92d7790dcffb191_1.png'},
#         'id': 'VnNTdGFnZS01'},
#        {'vsStageId': 9,
#         'name': 'Flounder Heights',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/488017f3ce712fca9fb37d61fe306343054449bb2d2bb1751d95f54a98564cae_1.png'},
#         'id': 'VnNTdGFnZS05'}],
#       'vsRule': {'name': 'Turf War',
#        'rule': 'TURF_WAR',
#        'id': 'VnNSdWxlLTA='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T10:00:00Z',
#      'endTime': '2023-10-20T12:00:00Z',
#      'regularMatchSetting': {'__isVsSetting': 'RegularMatchSetting',
#       '__typename': 'RegularMatchSetting',
#       'vsStages': [{'vsStageId': 8,
#         'name': 'Barnacle & Dime',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/f70e9f5af477a39ccfab631bfb81c9e2cedb4cd0947fe260847c214a6d23695f_1.png'},
#         'id': 'VnNTdGFnZS04'},
#        {'vsStageId': 15,
#         'name': 'MakoMart',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/a8ba96c3dbd015b7bc6ea4fa067245c4e9aee62b6696cb41e02d35139dd21fe7_1.png'},
#         'id': 'VnNTdGFnZS0xNQ=='}],
#       'vsRule': {'name': 'Turf War',
#        'rule': 'TURF_WAR',
#        'id': 'VnNSdWxlLTA='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T12:00:00Z',
#      'endTime': '2023-10-20T14:00:00Z',
#      'regularMatchSetting': {'__isVsSetting': 'RegularMatchSetting',
#       '__typename': 'RegularMatchSetting',
#       'vsStages': [{'vsStageId': 19,
#         'name': 'Crableg Capital',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/4e0e9e2046aff1d635e23946d9f0a461486d2aab349079e551037e426ac82c7a_1.png'},
#         'id': 'VnNTdGFnZS0xOQ=='},
#        {'vsStageId': 20,
#         'name': 'Shipshape Cargo Co.',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/b65a70eedf129848b9d2b492bb68712abf91a5cbda13131848947fb04c51d665_1.png'},
#         'id': 'VnNTdGFnZS0yMA=='}],
#       'vsRule': {'name': 'Turf War',
#        'rule': 'TURF_WAR',
#        'id': 'VnNSdWxlLTA='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T14:00:00Z',
#      'endTime': '2023-10-20T16:00:00Z',
#      'regularMatchSetting': {'__isVsSetting': 'RegularMatchSetting',
#       '__typename': 'RegularMatchSetting',
#       'vsStages': [{'vsStageId': 4,
#         'name': 'Undertow Spillway',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/9b1c17b2075479d0397d2fb96efbc6fa3a28900712920e5fe1e9dfc59c6abc5c_1.png'},
#         'id': 'VnNTdGFnZS00'},
#        {'vsStageId': 18,
#         'name': 'Manta Maria',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/0b7fd997781e03eb9d5bf1875ed070f698afc654f4fe929452c65aa26c0a35fd_1.png'},
#         'id': 'VnNTdGFnZS0xOA=='}],
#       'vsRule': {'name': 'Turf War',
#        'rule': 'TURF_WAR',
#        'id': 'VnNSdWxlLTA='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T16:00:00Z',
#      'endTime': '2023-10-20T18:00:00Z',
#      'regularMatchSetting': {'__isVsSetting': 'RegularMatchSetting',
#       '__typename': 'RegularMatchSetting',
#       'vsStages': [{'vsStageId': 3,
#         'name': 'Hagglefish Market',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/8dc2f16d39c630bab40cead5b2485ca3559e829d0d3de0c2232c7a62fefb5fa9_1.png'},
#         'id': 'VnNTdGFnZS0z'},
#        {'vsStageId': 17,
#         'name': 'Humpback Pump Track',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/7b3cf118bd9f45d141cd6db0ee75b06e697fa83945c7fe1e6f8483de6a591f5f_1.png'},
#         'id': 'VnNTdGFnZS0xNw=='}],
#       'vsRule': {'name': 'Turf War',
#        'rule': 'TURF_WAR',
#        'id': 'VnNSdWxlLTA='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T18:00:00Z',
#      'endTime': '2023-10-20T20:00:00Z',
#      'regularMatchSetting': {'__isVsSetting': 'RegularMatchSetting',
#       '__typename': 'RegularMatchSetting',
#       'vsStages': [{'vsStageId': 12,
#         'name': 'Mahi-Mahi Resort',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/8273118c1ffe1bf6fe031c7d8c9795dab52632c9b76e8e9f01f644ac5ae0ccc0_1.png'},
#         'id': 'VnNTdGFnZS0xMg=='},
#        {'vsStageId': 14,
#         'name': 'Sturgeon Shipyard',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/48684c69d5c5a4ffaf16b712a4895545a8d01196115d514fc878ce99863bb3e9_1.png'},
#         'id': 'VnNTdGFnZS0xNA=='}],
#       'vsRule': {'name': 'Turf War',
#        'rule': 'TURF_WAR',
#        'id': 'VnNSdWxlLTA='}},
#      'festMatchSettings': None}]},
#   'bankaraSchedules': {'nodes': [{'startTime': '2023-10-19T18:00:00Z',
#      'endTime': '2023-10-19T20:00:00Z',
#      'bankaraMatchSettings': [{'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 12,
#          'name': 'Mahi-Mahi Resort',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/8273118c1ffe1bf6fe031c7d8c9795dab52632c9b76e8e9f01f644ac5ae0ccc0_1.png'},
#          'id': 'VnNTdGFnZS0xMg=='},
#         {'vsStageId': 14,
#          'name': 'Sturgeon Shipyard',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/48684c69d5c5a4ffaf16b712a4895545a8d01196115d514fc878ce99863bb3e9_1.png'},
#          'id': 'VnNTdGFnZS0xNA=='}],
#        'vsRule': {'name': 'Splat Zones', 'rule': 'AREA', 'id': 'VnNSdWxlLTE='},
#        'bankaraMode': 'CHALLENGE'},
#       {'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 17,
#          'name': 'Humpback Pump Track',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/7b3cf118bd9f45d141cd6db0ee75b06e697fa83945c7fe1e6f8483de6a591f5f_1.png'},
#          'id': 'VnNTdGFnZS0xNw=='},
#         {'vsStageId': 18,
#          'name': 'Manta Maria',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/0b7fd997781e03eb9d5bf1875ed070f698afc654f4fe929452c65aa26c0a35fd_1.png'},
#          'id': 'VnNTdGFnZS0xOA=='}],
#        'vsRule': {'name': 'Clam Blitz', 'rule': 'CLAM', 'id': 'VnNSdWxlLTQ='},
#        'bankaraMode': 'OPEN'}],
#      'festMatchSettings': None},
#     {'startTime': '2023-10-19T20:00:00Z',
#      'endTime': '2023-10-19T22:00:00Z',
#      'bankaraMatchSettings': [{'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 12,
#          'name': 'Mahi-Mahi Resort',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/8273118c1ffe1bf6fe031c7d8c9795dab52632c9b76e8e9f01f644ac5ae0ccc0_1.png'},
#          'id': 'VnNTdGFnZS0xMg=='},
#         {'vsStageId': 18,
#          'name': 'Manta Maria',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/0b7fd997781e03eb9d5bf1875ed070f698afc654f4fe929452c65aa26c0a35fd_1.png'},
#          'id': 'VnNTdGFnZS0xOA=='}],
#        'vsRule': {'name': 'Tower Control',
#         'rule': 'LOFT',
#         'id': 'VnNSdWxlLTI='},
#        'bankaraMode': 'CHALLENGE'},
#       {'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 12,
#          'name': 'Mahi-Mahi Resort',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/8273118c1ffe1bf6fe031c7d8c9795dab52632c9b76e8e9f01f644ac5ae0ccc0_1.png'},
#          'id': 'VnNTdGFnZS0xMg=='},
#         {'vsStageId': 16,
#          'name': 'Wahoo World',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/61ea801fa4ed32360dcaf83986222ded46a72dbf56194acc6d0cf4659a92ba85_1.png'},
#          'id': 'VnNTdGFnZS0xNg=='}],
#        'vsRule': {'name': 'Rainmaker', 'rule': 'GOAL', 'id': 'VnNSdWxlLTM='},
#        'bankaraMode': 'OPEN'}],
#      'festMatchSettings': None},
#     {'startTime': '2023-10-19T22:00:00Z',
#      'endTime': '2023-10-20T00:00:00Z',
#      'bankaraMatchSettings': [{'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 1,
#          'name': 'Scorch Gorge',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/35f9ca08ccc2bf759774ab2cb886567c117b9287875ca92fb590c1294ddcdc1e_1.png'},
#          'id': 'VnNTdGFnZS0x'},
#         {'vsStageId': 13,
#          'name': 'Inkblot Art Academy',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/40aba8b36a9439e2d670fde5b3478819ea8a94f9e503b9d783248a5716786f35_1.png'},
#          'id': 'VnNTdGFnZS0xMw=='}],
#        'vsRule': {'name': 'Clam Blitz', 'rule': 'CLAM', 'id': 'VnNSdWxlLTQ='},
#        'bankaraMode': 'CHALLENGE'},
#       {'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 10,
#          'name': 'Hammerhead Bridge',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/1db8ab338b64b464df50e7f9e270e59423ff8caac6f09679a24f1b7acf3a82f3_1.png'},
#          'id': 'VnNTdGFnZS0xMA=='},
#         {'vsStageId': 15,
#          'name': 'MakoMart',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/a8ba96c3dbd015b7bc6ea4fa067245c4e9aee62b6696cb41e02d35139dd21fe7_1.png'},
#          'id': 'VnNTdGFnZS0xNQ=='}],
#        'vsRule': {'name': 'Splat Zones', 'rule': 'AREA', 'id': 'VnNSdWxlLTE='},
#        'bankaraMode': 'OPEN'}],
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T00:00:00Z',
#      'endTime': '2023-10-20T02:00:00Z',
#      'bankaraMatchSettings': [{'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 1,
#          'name': 'Scorch Gorge',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/35f9ca08ccc2bf759774ab2cb886567c117b9287875ca92fb590c1294ddcdc1e_1.png'},
#          'id': 'VnNTdGFnZS0x'},
#         {'vsStageId': 12,
#          'name': 'Mahi-Mahi Resort',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/8273118c1ffe1bf6fe031c7d8c9795dab52632c9b76e8e9f01f644ac5ae0ccc0_1.png'},
#          'id': 'VnNTdGFnZS0xMg=='}],
#        'vsRule': {'name': 'Splat Zones', 'rule': 'AREA', 'id': 'VnNSdWxlLTE='},
#        'bankaraMode': 'CHALLENGE'},
#       {'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 8,
#          'name': 'Barnacle & Dime',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/f70e9f5af477a39ccfab631bfb81c9e2cedb4cd0947fe260847c214a6d23695f_1.png'},
#          'id': 'VnNTdGFnZS04'},
#         {'vsStageId': 11,
#          'name': "Museum d'Alfonsino",
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/b9d8cfa186d197a27e075600a107c99d9e21646d116730f0843e0fff0aaba7dd_1.png'},
#          'id': 'VnNTdGFnZS0xMQ=='}],
#        'vsRule': {'name': 'Rainmaker', 'rule': 'GOAL', 'id': 'VnNSdWxlLTM='},
#        'bankaraMode': 'OPEN'}],
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T02:00:00Z',
#      'endTime': '2023-10-20T04:00:00Z',
#      'bankaraMatchSettings': [{'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 7,
#          'name': 'Brinewater Springs',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/cd84d711b47a424334569ac20f33f8e0ab6a652dc07854dcd36508a0081e9034_1.png'},
#          'id': 'VnNTdGFnZS03'},
#         {'vsStageId': 10,
#          'name': 'Hammerhead Bridge',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/1db8ab338b64b464df50e7f9e270e59423ff8caac6f09679a24f1b7acf3a82f3_1.png'},
#          'id': 'VnNTdGFnZS0xMA=='}],
#        'vsRule': {'name': 'Clam Blitz', 'rule': 'CLAM', 'id': 'VnNSdWxlLTQ='},
#        'bankaraMode': 'CHALLENGE'},
#       {'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 6,
#          'name': 'Mincemeat Metalworks',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/de1f212e9ff0648f36cd3b8e0917ef36b3bd51445159297dcb948f34a09f2f05_1.png'},
#          'id': 'VnNTdGFnZS02'},
#         {'vsStageId': 9,
#          'name': 'Flounder Heights',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/488017f3ce712fca9fb37d61fe306343054449bb2d2bb1751d95f54a98564cae_1.png'},
#          'id': 'VnNTdGFnZS05'}],
#        'vsRule': {'name': 'Tower Control',
#         'rule': 'LOFT',
#         'id': 'VnNSdWxlLTI='},
#        'bankaraMode': 'OPEN'}],
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T04:00:00Z',
#      'endTime': '2023-10-20T06:00:00Z',
#      'bankaraMatchSettings': [{'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 8,
#          'name': 'Barnacle & Dime',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/f70e9f5af477a39ccfab631bfb81c9e2cedb4cd0947fe260847c214a6d23695f_1.png'},
#          'id': 'VnNTdGFnZS04'},
#         {'vsStageId': 20,
#          'name': 'Shipshape Cargo Co.',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/b65a70eedf129848b9d2b492bb68712abf91a5cbda13131848947fb04c51d665_1.png'},
#          'id': 'VnNTdGFnZS0yMA=='}],
#        'vsRule': {'name': 'Rainmaker', 'rule': 'GOAL', 'id': 'VnNSdWxlLTM='},
#        'bankaraMode': 'CHALLENGE'},
#       {'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 4,
#          'name': 'Undertow Spillway',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/9b1c17b2075479d0397d2fb96efbc6fa3a28900712920e5fe1e9dfc59c6abc5c_1.png'},
#          'id': 'VnNTdGFnZS00'},
#         {'vsStageId': 5,
#          'name': "Um'ami Ruins",
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/f14c2a64e49d243679fc0884af91e1a07dc65600f9b90aefe92d7790dcffb191_1.png'},
#          'id': 'VnNTdGFnZS01'}],
#        'vsRule': {'name': 'Splat Zones', 'rule': 'AREA', 'id': 'VnNSdWxlLTE='},
#        'bankaraMode': 'OPEN'}],
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T06:00:00Z',
#      'endTime': '2023-10-20T08:00:00Z',
#      'bankaraMatchSettings': [{'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 2,
#          'name': 'Eeltail Alley',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/898e1ae6c737a9d44552c7c81f9b710676492681525c514eadc68a6780aa52af_1.png'},
#          'id': 'VnNTdGFnZS0y'},
#         {'vsStageId': 5,
#          'name': "Um'ami Ruins",
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/f14c2a64e49d243679fc0884af91e1a07dc65600f9b90aefe92d7790dcffb191_1.png'},
#          'id': 'VnNTdGFnZS01'}],
#        'vsRule': {'name': 'Tower Control',
#         'rule': 'LOFT',
#         'id': 'VnNSdWxlLTI='},
#        'bankaraMode': 'CHALLENGE'},
#       {'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 3,
#          'name': 'Hagglefish Market',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/8dc2f16d39c630bab40cead5b2485ca3559e829d0d3de0c2232c7a62fefb5fa9_1.png'},
#          'id': 'VnNTdGFnZS0z'},
#         {'vsStageId': 7,
#          'name': 'Brinewater Springs',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/cd84d711b47a424334569ac20f33f8e0ab6a652dc07854dcd36508a0081e9034_1.png'},
#          'id': 'VnNTdGFnZS03'}],
#        'vsRule': {'name': 'Clam Blitz', 'rule': 'CLAM', 'id': 'VnNSdWxlLTQ='},
#        'bankaraMode': 'OPEN'}],
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T08:00:00Z',
#      'endTime': '2023-10-20T10:00:00Z',
#      'bankaraMatchSettings': [{'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 3,
#          'name': 'Hagglefish Market',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/8dc2f16d39c630bab40cead5b2485ca3559e829d0d3de0c2232c7a62fefb5fa9_1.png'},
#          'id': 'VnNTdGFnZS0z'},
#         {'vsStageId': 18,
#          'name': 'Manta Maria',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/0b7fd997781e03eb9d5bf1875ed070f698afc654f4fe929452c65aa26c0a35fd_1.png'},
#          'id': 'VnNTdGFnZS0xOA=='}],
#        'vsRule': {'name': 'Splat Zones', 'rule': 'AREA', 'id': 'VnNSdWxlLTE='},
#        'bankaraMode': 'CHALLENGE'},
#       {'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 2,
#          'name': 'Eeltail Alley',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/898e1ae6c737a9d44552c7c81f9b710676492681525c514eadc68a6780aa52af_1.png'},
#          'id': 'VnNTdGFnZS0y'},
#         {'vsStageId': 20,
#          'name': 'Shipshape Cargo Co.',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/b65a70eedf129848b9d2b492bb68712abf91a5cbda13131848947fb04c51d665_1.png'},
#          'id': 'VnNTdGFnZS0yMA=='}],
#        'vsRule': {'name': 'Rainmaker', 'rule': 'GOAL', 'id': 'VnNSdWxlLTM='},
#        'bankaraMode': 'OPEN'}],
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T10:00:00Z',
#      'endTime': '2023-10-20T12:00:00Z',
#      'bankaraMatchSettings': [{'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 9,
#          'name': 'Flounder Heights',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/488017f3ce712fca9fb37d61fe306343054449bb2d2bb1751d95f54a98564cae_1.png'},
#          'id': 'VnNTdGFnZS05'},
#         {'vsStageId': 17,
#          'name': 'Humpback Pump Track',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/7b3cf118bd9f45d141cd6db0ee75b06e697fa83945c7fe1e6f8483de6a591f5f_1.png'},
#          'id': 'VnNTdGFnZS0xNw=='}],
#        'vsRule': {'name': 'Clam Blitz', 'rule': 'CLAM', 'id': 'VnNSdWxlLTQ='},
#        'bankaraMode': 'CHALLENGE'},
#       {'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 18,
#          'name': 'Manta Maria',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/0b7fd997781e03eb9d5bf1875ed070f698afc654f4fe929452c65aa26c0a35fd_1.png'},
#          'id': 'VnNTdGFnZS0xOA=='},
#         {'vsStageId': 19,
#          'name': 'Crableg Capital',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/4e0e9e2046aff1d635e23946d9f0a461486d2aab349079e551037e426ac82c7a_1.png'},
#          'id': 'VnNTdGFnZS0xOQ=='}],
#        'vsRule': {'name': 'Tower Control',
#         'rule': 'LOFT',
#         'id': 'VnNSdWxlLTI='},
#        'bankaraMode': 'OPEN'}],
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T12:00:00Z',
#      'endTime': '2023-10-20T14:00:00Z',
#      'bankaraMatchSettings': [{'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 12,
#          'name': 'Mahi-Mahi Resort',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/8273118c1ffe1bf6fe031c7d8c9795dab52632c9b76e8e9f01f644ac5ae0ccc0_1.png'},
#          'id': 'VnNTdGFnZS0xMg=='},
#         {'vsStageId': 13,
#          'name': 'Inkblot Art Academy',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/40aba8b36a9439e2d670fde5b3478819ea8a94f9e503b9d783248a5716786f35_1.png'},
#          'id': 'VnNTdGFnZS0xMw=='}],
#        'vsRule': {'name': 'Rainmaker', 'rule': 'GOAL', 'id': 'VnNSdWxlLTM='},
#        'bankaraMode': 'CHALLENGE'},
#       {'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 4,
#          'name': 'Undertow Spillway',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/9b1c17b2075479d0397d2fb96efbc6fa3a28900712920e5fe1e9dfc59c6abc5c_1.png'},
#          'id': 'VnNTdGFnZS00'},
#         {'vsStageId': 14,
#          'name': 'Sturgeon Shipyard',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/48684c69d5c5a4ffaf16b712a4895545a8d01196115d514fc878ce99863bb3e9_1.png'},
#          'id': 'VnNTdGFnZS0xNA=='}],
#        'vsRule': {'name': 'Splat Zones', 'rule': 'AREA', 'id': 'VnNSdWxlLTE='},
#        'bankaraMode': 'OPEN'}],
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T14:00:00Z',
#      'endTime': '2023-10-20T16:00:00Z',
#      'bankaraMatchSettings': [{'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 16,
#          'name': 'Wahoo World',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/61ea801fa4ed32360dcaf83986222ded46a72dbf56194acc6d0cf4659a92ba85_1.png'},
#          'id': 'VnNTdGFnZS0xNg=='},
#         {'vsStageId': 19,
#          'name': 'Crableg Capital',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/4e0e9e2046aff1d635e23946d9f0a461486d2aab349079e551037e426ac82c7a_1.png'},
#          'id': 'VnNTdGFnZS0xOQ=='}],
#        'vsRule': {'name': 'Tower Control',
#         'rule': 'LOFT',
#         'id': 'VnNSdWxlLTI='},
#        'bankaraMode': 'CHALLENGE'},
#       {'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 6,
#          'name': 'Mincemeat Metalworks',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/de1f212e9ff0648f36cd3b8e0917ef36b3bd51445159297dcb948f34a09f2f05_1.png'},
#          'id': 'VnNTdGFnZS02'},
#         {'vsStageId': 17,
#          'name': 'Humpback Pump Track',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/7b3cf118bd9f45d141cd6db0ee75b06e697fa83945c7fe1e6f8483de6a591f5f_1.png'},
#          'id': 'VnNTdGFnZS0xNw=='}],
#        'vsRule': {'name': 'Clam Blitz', 'rule': 'CLAM', 'id': 'VnNSdWxlLTQ='},
#        'bankaraMode': 'OPEN'}],
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T16:00:00Z',
#      'endTime': '2023-10-20T18:00:00Z',
#      'bankaraMatchSettings': [{'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 14,
#          'name': 'Sturgeon Shipyard',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/48684c69d5c5a4ffaf16b712a4895545a8d01196115d514fc878ce99863bb3e9_1.png'},
#          'id': 'VnNTdGFnZS0xNA=='},
#         {'vsStageId': 15,
#          'name': 'MakoMart',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/a8ba96c3dbd015b7bc6ea4fa067245c4e9aee62b6696cb41e02d35139dd21fe7_1.png'},
#          'id': 'VnNTdGFnZS0xNQ=='}],
#        'vsRule': {'name': 'Splat Zones', 'rule': 'AREA', 'id': 'VnNSdWxlLTE='},
#        'bankaraMode': 'CHALLENGE'},
#       {'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 13,
#          'name': 'Inkblot Art Academy',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/40aba8b36a9439e2d670fde5b3478819ea8a94f9e503b9d783248a5716786f35_1.png'},
#          'id': 'VnNTdGFnZS0xMw=='},
#         {'vsStageId': 16,
#          'name': 'Wahoo World',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/61ea801fa4ed32360dcaf83986222ded46a72dbf56194acc6d0cf4659a92ba85_1.png'},
#          'id': 'VnNTdGFnZS0xNg=='}],
#        'vsRule': {'name': 'Rainmaker', 'rule': 'GOAL', 'id': 'VnNSdWxlLTM='},
#        'bankaraMode': 'OPEN'}],
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T18:00:00Z',
#      'endTime': '2023-10-20T20:00:00Z',
#      'bankaraMatchSettings': [{'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 7,
#          'name': 'Brinewater Springs',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/cd84d711b47a424334569ac20f33f8e0ab6a652dc07854dcd36508a0081e9034_1.png'},
#          'id': 'VnNTdGFnZS03'},
#         {'vsStageId': 11,
#          'name': "Museum d'Alfonsino",
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/b9d8cfa186d197a27e075600a107c99d9e21646d116730f0843e0fff0aaba7dd_1.png'},
#          'id': 'VnNTdGFnZS0xMQ=='}],
#        'vsRule': {'name': 'Clam Blitz', 'rule': 'CLAM', 'id': 'VnNSdWxlLTQ='},
#        'bankaraMode': 'CHALLENGE'},
#       {'__isVsSetting': 'BankaraMatchSetting',
#        '__typename': 'BankaraMatchSetting',
#        'vsStages': [{'vsStageId': 9,
#          'name': 'Flounder Heights',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/488017f3ce712fca9fb37d61fe306343054449bb2d2bb1751d95f54a98564cae_1.png'},
#          'id': 'VnNTdGFnZS05'},
#         {'vsStageId': 15,
#          'name': 'MakoMart',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/a8ba96c3dbd015b7bc6ea4fa067245c4e9aee62b6696cb41e02d35139dd21fe7_1.png'},
#          'id': 'VnNTdGFnZS0xNQ=='}],
#        'vsRule': {'name': 'Tower Control',
#         'rule': 'LOFT',
#         'id': 'VnNSdWxlLTI='},
#        'bankaraMode': 'OPEN'}],
#      'festMatchSettings': None}]},
#   'xSchedules': {'nodes': [{'startTime': '2023-10-19T18:00:00Z',
#      'endTime': '2023-10-19T20:00:00Z',
#      'xMatchSetting': {'__isVsSetting': 'XMatchSetting',
#       '__typename': 'XMatchSetting',
#       'vsStages': [{'vsStageId': 4,
#         'name': 'Undertow Spillway',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/9b1c17b2075479d0397d2fb96efbc6fa3a28900712920e5fe1e9dfc59c6abc5c_1.png'},
#         'id': 'VnNTdGFnZS00'},
#        {'vsStageId': 20,
#         'name': 'Shipshape Cargo Co.',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/b65a70eedf129848b9d2b492bb68712abf91a5cbda13131848947fb04c51d665_1.png'},
#         'id': 'VnNTdGFnZS0yMA=='}],
#       'vsRule': {'name': 'Rainmaker', 'rule': 'GOAL', 'id': 'VnNSdWxlLTM='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-19T20:00:00Z',
#      'endTime': '2023-10-19T22:00:00Z',
#      'xMatchSetting': {'__isVsSetting': 'XMatchSetting',
#       '__typename': 'XMatchSetting',
#       'vsStages': [{'vsStageId': 14,
#         'name': 'Sturgeon Shipyard',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/48684c69d5c5a4ffaf16b712a4895545a8d01196115d514fc878ce99863bb3e9_1.png'},
#         'id': 'VnNTdGFnZS0xNA=='},
#        {'vsStageId': 19,
#         'name': 'Crableg Capital',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/4e0e9e2046aff1d635e23946d9f0a461486d2aab349079e551037e426ac82c7a_1.png'},
#         'id': 'VnNTdGFnZS0xOQ=='}],
#       'vsRule': {'name': 'Splat Zones', 'rule': 'AREA', 'id': 'VnNSdWxlLTE='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-19T22:00:00Z',
#      'endTime': '2023-10-20T00:00:00Z',
#      'xMatchSetting': {'__isVsSetting': 'XMatchSetting',
#       '__typename': 'XMatchSetting',
#       'vsStages': [{'vsStageId': 5,
#         'name': "Um'ami Ruins",
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/f14c2a64e49d243679fc0884af91e1a07dc65600f9b90aefe92d7790dcffb191_1.png'},
#         'id': 'VnNTdGFnZS01'},
#        {'vsStageId': 12,
#         'name': 'Mahi-Mahi Resort',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/8273118c1ffe1bf6fe031c7d8c9795dab52632c9b76e8e9f01f644ac5ae0ccc0_1.png'},
#         'id': 'VnNTdGFnZS0xMg=='}],
#       'vsRule': {'name': 'Tower Control',
#        'rule': 'LOFT',
#        'id': 'VnNSdWxlLTI='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T00:00:00Z',
#      'endTime': '2023-10-20T02:00:00Z',
#      'xMatchSetting': {'__isVsSetting': 'XMatchSetting',
#       '__typename': 'XMatchSetting',
#       'vsStages': [{'vsStageId': 12,
#         'name': 'Mahi-Mahi Resort',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/8273118c1ffe1bf6fe031c7d8c9795dab52632c9b76e8e9f01f644ac5ae0ccc0_1.png'},
#         'id': 'VnNTdGFnZS0xMg=='},
#        {'vsStageId': 18,
#         'name': 'Manta Maria',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/0b7fd997781e03eb9d5bf1875ed070f698afc654f4fe929452c65aa26c0a35fd_1.png'},
#         'id': 'VnNTdGFnZS0xOA=='}],
#       'vsRule': {'name': 'Clam Blitz', 'rule': 'CLAM', 'id': 'VnNSdWxlLTQ='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T02:00:00Z',
#      'endTime': '2023-10-20T04:00:00Z',
#      'xMatchSetting': {'__isVsSetting': 'XMatchSetting',
#       '__typename': 'XMatchSetting',
#       'vsStages': [{'vsStageId': 2,
#         'name': 'Eeltail Alley',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/898e1ae6c737a9d44552c7c81f9b710676492681525c514eadc68a6780aa52af_1.png'},
#         'id': 'VnNTdGFnZS0y'},
#        {'vsStageId': 17,
#         'name': 'Humpback Pump Track',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/7b3cf118bd9f45d141cd6db0ee75b06e697fa83945c7fe1e6f8483de6a591f5f_1.png'},
#         'id': 'VnNTdGFnZS0xNw=='}],
#       'vsRule': {'name': 'Splat Zones', 'rule': 'AREA', 'id': 'VnNSdWxlLTE='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T04:00:00Z',
#      'endTime': '2023-10-20T06:00:00Z',
#      'xMatchSetting': {'__isVsSetting': 'XMatchSetting',
#       '__typename': 'XMatchSetting',
#       'vsStages': [{'vsStageId': 15,
#         'name': 'MakoMart',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/a8ba96c3dbd015b7bc6ea4fa067245c4e9aee62b6696cb41e02d35139dd21fe7_1.png'},
#         'id': 'VnNTdGFnZS0xNQ=='},
#        {'vsStageId': 18,
#         'name': 'Manta Maria',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/0b7fd997781e03eb9d5bf1875ed070f698afc654f4fe929452c65aa26c0a35fd_1.png'},
#         'id': 'VnNTdGFnZS0xOA=='}],
#       'vsRule': {'name': 'Tower Control',
#        'rule': 'LOFT',
#        'id': 'VnNSdWxlLTI='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T06:00:00Z',
#      'endTime': '2023-10-20T08:00:00Z',
#      'xMatchSetting': {'__isVsSetting': 'XMatchSetting',
#       '__typename': 'XMatchSetting',
#       'vsStages': [{'vsStageId': 8,
#         'name': 'Barnacle & Dime',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/f70e9f5af477a39ccfab631bfb81c9e2cedb4cd0947fe260847c214a6d23695f_1.png'},
#         'id': 'VnNTdGFnZS04'},
#        {'vsStageId': 20,
#         'name': 'Shipshape Cargo Co.',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/b65a70eedf129848b9d2b492bb68712abf91a5cbda13131848947fb04c51d665_1.png'},
#         'id': 'VnNTdGFnZS0yMA=='}],
#       'vsRule': {'name': 'Rainmaker', 'rule': 'GOAL', 'id': 'VnNSdWxlLTM='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T08:00:00Z',
#      'endTime': '2023-10-20T10:00:00Z',
#      'xMatchSetting': {'__isVsSetting': 'XMatchSetting',
#       '__typename': 'XMatchSetting',
#       'vsStages': [{'vsStageId': 16,
#         'name': 'Wahoo World',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/61ea801fa4ed32360dcaf83986222ded46a72dbf56194acc6d0cf4659a92ba85_1.png'},
#         'id': 'VnNTdGFnZS0xNg=='},
#        {'vsStageId': 19,
#         'name': 'Crableg Capital',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/4e0e9e2046aff1d635e23946d9f0a461486d2aab349079e551037e426ac82c7a_1.png'},
#         'id': 'VnNTdGFnZS0xOQ=='}],
#       'vsRule': {'name': 'Clam Blitz', 'rule': 'CLAM', 'id': 'VnNSdWxlLTQ='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T10:00:00Z',
#      'endTime': '2023-10-20T12:00:00Z',
#      'xMatchSetting': {'__isVsSetting': 'XMatchSetting',
#       '__typename': 'XMatchSetting',
#       'vsStages': [{'vsStageId': 3,
#         'name': 'Hagglefish Market',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/8dc2f16d39c630bab40cead5b2485ca3559e829d0d3de0c2232c7a62fefb5fa9_1.png'},
#         'id': 'VnNTdGFnZS0z'},
#        {'vsStageId': 6,
#         'name': 'Mincemeat Metalworks',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/de1f212e9ff0648f36cd3b8e0917ef36b3bd51445159297dcb948f34a09f2f05_1.png'},
#         'id': 'VnNTdGFnZS02'}],
#       'vsRule': {'name': 'Splat Zones', 'rule': 'AREA', 'id': 'VnNSdWxlLTE='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T12:00:00Z',
#      'endTime': '2023-10-20T14:00:00Z',
#      'xMatchSetting': {'__isVsSetting': 'XMatchSetting',
#       '__typename': 'XMatchSetting',
#       'vsStages': [{'vsStageId': 15,
#         'name': 'MakoMart',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/a8ba96c3dbd015b7bc6ea4fa067245c4e9aee62b6696cb41e02d35139dd21fe7_1.png'},
#         'id': 'VnNTdGFnZS0xNQ=='},
#        {'vsStageId': 17,
#         'name': 'Humpback Pump Track',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/7b3cf118bd9f45d141cd6db0ee75b06e697fa83945c7fe1e6f8483de6a591f5f_1.png'},
#         'id': 'VnNTdGFnZS0xNw=='}],
#       'vsRule': {'name': 'Tower Control',
#        'rule': 'LOFT',
#        'id': 'VnNSdWxlLTI='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T14:00:00Z',
#      'endTime': '2023-10-20T16:00:00Z',
#      'xMatchSetting': {'__isVsSetting': 'XMatchSetting',
#       '__typename': 'XMatchSetting',
#       'vsStages': [{'vsStageId': 13,
#         'name': 'Inkblot Art Academy',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/40aba8b36a9439e2d670fde5b3478819ea8a94f9e503b9d783248a5716786f35_1.png'},
#         'id': 'VnNTdGFnZS0xMw=='},
#        {'vsStageId': 14,
#         'name': 'Sturgeon Shipyard',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/48684c69d5c5a4ffaf16b712a4895545a8d01196115d514fc878ce99863bb3e9_1.png'},
#         'id': 'VnNTdGFnZS0xNA=='}],
#       'vsRule': {'name': 'Rainmaker', 'rule': 'GOAL', 'id': 'VnNSdWxlLTM='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T16:00:00Z',
#      'endTime': '2023-10-20T18:00:00Z',
#      'xMatchSetting': {'__isVsSetting': 'XMatchSetting',
#       '__typename': 'XMatchSetting',
#       'vsStages': [{'vsStageId': 4,
#         'name': 'Undertow Spillway',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/9b1c17b2075479d0397d2fb96efbc6fa3a28900712920e5fe1e9dfc59c6abc5c_1.png'},
#         'id': 'VnNTdGFnZS00'},
#        {'vsStageId': 12,
#         'name': 'Mahi-Mahi Resort',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/8273118c1ffe1bf6fe031c7d8c9795dab52632c9b76e8e9f01f644ac5ae0ccc0_1.png'},
#         'id': 'VnNTdGFnZS0xMg=='}],
#       'vsRule': {'name': 'Clam Blitz', 'rule': 'CLAM', 'id': 'VnNSdWxlLTQ='}},
#      'festMatchSettings': None},
#     {'startTime': '2023-10-20T18:00:00Z',
#      'endTime': '2023-10-20T20:00:00Z',
#      'xMatchSetting': {'__isVsSetting': 'XMatchSetting',
#       '__typename': 'XMatchSetting',
#       'vsStages': [{'vsStageId': 3,
#         'name': 'Hagglefish Market',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/8dc2f16d39c630bab40cead5b2485ca3559e829d0d3de0c2232c7a62fefb5fa9_1.png'},
#         'id': 'VnNTdGFnZS0z'},
#        {'vsStageId': 10,
#         'name': 'Hammerhead Bridge',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/1db8ab338b64b464df50e7f9e270e59423ff8caac6f09679a24f1b7acf3a82f3_1.png'},
#         'id': 'VnNTdGFnZS0xMA=='}],
#       'vsRule': {'name': 'Splat Zones', 'rule': 'AREA', 'id': 'VnNSdWxlLTE='}},
#      'festMatchSettings': None}]},
#   'eventSchedules': {'nodes': [{'leagueMatchSetting': {'leagueMatchEvent': {'leagueMatchEventId': 'CostumeParty',
#        'name': "Sheldon's Dress-Up Showdown",
#        'desc': "Raid Sheldon's arsenal and closet for<br />random weapons and outfits!",
#        'regulationUrl': None,
#        'regulation': "Make the most of a random assortment of Sheldon's weapons and outfits in this come-as-you-are Challenge!<br /><br />・ You'll be assigned an outfit and weapon at the start of battle.<br />・ Your loadout will completely change with each subsequent battle!<br />・ Sheldon is graciously loaning all of the equipment, so you don't need to own the items you're using. You also don't get to keep them.",
#        'id': 'TGVhZ3VlTWF0Y2hFdmVudC1Db3N0dW1lUGFydHk='},
#       'vsStages': [{'vsStageId': 5,
#         'name': "Um'ami Ruins",
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/f14c2a64e49d243679fc0884af91e1a07dc65600f9b90aefe92d7790dcffb191_1.png'},
#         'id': 'VnNTdGFnZS01'},
#        {'vsStageId': 8,
#         'name': 'Barnacle & Dime',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/f70e9f5af477a39ccfab631bfb81c9e2cedb4cd0947fe260847c214a6d23695f_1.png'},
#         'id': 'VnNTdGFnZS04'}],
#       '__isVsSetting': 'LeagueMatchSetting',
#       '__typename': 'LeagueMatchSetting',
#       'vsRule': {'name': 'Tower Control',
#        'rule': 'LOFT',
#        'id': 'VnNSdWxlLTI='}},
#      'timePeriods': [{'startTime': '2023-10-22T04:00:00Z',
#        'endTime': '2023-10-22T06:00:00Z'},
#       {'startTime': '2023-10-22T12:00:00Z', 'endTime': '2023-10-22T14:00:00Z'},
#       {'startTime': '2023-10-22T20:00:00Z',
#        'endTime': '2023-10-22T22:00:00Z'}]},
#     {'leagueMatchSetting': {'leagueMatchEvent': {'leagueMatchEventId': 'WeaponLimited_Spinner',
#        'name': 'Barrel of Splats',
#        'desc': 'Muster as much firepower as you can<br />in this battle of the splatlings!',
#        'regulationUrl': None,
#        'regulation': "Bring the heat with your best splatling loadout, and see who's left standing.<br /><br />・ Players can only choose different varieties of splatlings!<br />・ Both primary and secondary abilities will be enabled.",
#        'id': 'TGVhZ3VlTWF0Y2hFdmVudC1XZWFwb25MaW1pdGVkX1NwaW5uZXI='},
#       'vsStages': [{'vsStageId': 4,
#         'name': 'Undertow Spillway',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/9b1c17b2075479d0397d2fb96efbc6fa3a28900712920e5fe1e9dfc59c6abc5c_1.png'},
#         'id': 'VnNTdGFnZS00'},
#        {'vsStageId': 9,
#         'name': 'Flounder Heights',
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/488017f3ce712fca9fb37d61fe306343054449bb2d2bb1751d95f54a98564cae_1.png'},
#         'id': 'VnNTdGFnZS05'}],
#       '__isVsSetting': 'LeagueMatchSetting',
#       '__typename': 'LeagueMatchSetting',
#       'vsRule': {'name': 'Tower Control',
#        'rule': 'LOFT',
#        'id': 'VnNSdWxlLTI='}},
#      'timePeriods': [{'startTime': '2023-10-25T02:00:00Z',
#        'endTime': '2023-10-25T04:00:00Z'},
#       {'startTime': '2023-10-25T10:00:00Z', 'endTime': '2023-10-25T12:00:00Z'},
#       {'startTime': '2023-10-25T18:00:00Z',
#        'endTime': '2023-10-25T20:00:00Z'}]}]},
#   'festSchedules': {'nodes': [{'startTime': '2023-10-19T18:00:00Z',
#      'festMatchSettings': None,
#      'endTime': '2023-10-19T20:00:00Z'},
#     {'startTime': '2023-10-19T20:00:00Z',
#      'festMatchSettings': None,
#      'endTime': '2023-10-19T22:00:00Z'},
#     {'startTime': '2023-10-19T22:00:00Z',
#      'festMatchSettings': None,
#      'endTime': '2023-10-20T00:00:00Z'},
#     {'startTime': '2023-10-20T00:00:00Z',
#      'festMatchSettings': None,
#      'endTime': '2023-10-20T02:00:00Z'},
#     {'startTime': '2023-10-20T02:00:00Z',
#      'festMatchSettings': None,
#      'endTime': '2023-10-20T04:00:00Z'},
#     {'startTime': '2023-10-20T04:00:00Z',
#      'festMatchSettings': None,
#      'endTime': '2023-10-20T06:00:00Z'},
#     {'startTime': '2023-10-20T06:00:00Z',
#      'festMatchSettings': None,
#      'endTime': '2023-10-20T08:00:00Z'},
#     {'startTime': '2023-10-20T08:00:00Z',
#      'festMatchSettings': None,
#      'endTime': '2023-10-20T10:00:00Z'},
#     {'startTime': '2023-10-20T10:00:00Z',
#      'festMatchSettings': None,
#      'endTime': '2023-10-20T12:00:00Z'},
#     {'startTime': '2023-10-20T12:00:00Z',
#      'festMatchSettings': None,
#      'endTime': '2023-10-20T14:00:00Z'},
#     {'startTime': '2023-10-20T14:00:00Z',
#      'festMatchSettings': None,
#      'endTime': '2023-10-20T16:00:00Z'},
#     {'startTime': '2023-10-20T16:00:00Z',
#      'festMatchSettings': None,
#      'endTime': '2023-10-20T18:00:00Z'},
#     {'startTime': '2023-10-20T18:00:00Z',
#      'festMatchSettings': None,
#      'endTime': '2023-10-20T20:00:00Z'}]},
#   'coopGroupingSchedule': {'bannerImage': None,
#    'regularSchedules': {'nodes': [{'startTime': '2023-10-19T00:00:00Z',
#       'endTime': '2023-10-20T16:00:00Z',
#       'setting': {'__typename': 'CoopNormalSetting',
#        'coopStage': {'name': "Jammin' Salmon Junction",
#         'thumbnailImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/0e05d4caa34089a447535708370286f4ee6068661359b4d7cf6c319863424f84_1.png'},
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/0e05d4caa34089a447535708370286f4ee6068661359b4d7cf6c319863424f84_0.png'},
#         'id': 'Q29vcFN0YWdlLTg='},
#        '__isCoopSetting': 'CoopNormalSetting',
#        'weapons': [{'__splatoon3ink_id': '0a115698cc8dc6ca',
#          'name': 'Sloshing Machine',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/weapon_illust/bd2eca9a7b4109c1d96e804c74aaf2ca525011e1348d0b312fe4f034e35e5d4c_0.png'}},
#         {'__splatoon3ink_id': '310a426d80bfdfa2',
#          'name': 'Flingza Roller',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/weapon_illust/8351e99589f03f49b5d681d36b083aaffd9c486a0558ab957ac44b0db0bb58bb_0.png'}},
#         {'__splatoon3ink_id': '354c11e2554de95a',
#          'name': 'Splattershot Pro',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/weapon_illust/5607f7014bbc7339feeb67218c05ef19c7a466152b1bd056a899b955127ea433_0.png'}},
#         {'__splatoon3ink_id': '4131c07c5976c5ef',
#          'name': 'Splat Charger',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/weapon_illust/3f99800b569e286305669b7ab28dc3ff0f0b1b015600569d5ac30ab8a97047a0_0.png'}}]},
#       '__splatoon3ink_king_salmonid_guess': 'Horrorboros'},
#      {'startTime': '2023-10-20T16:00:00Z',
#       'endTime': '2023-10-22T08:00:00Z',
#       'setting': {'__typename': 'CoopNormalSetting',
#        'coopStage': {'name': 'Spawning Grounds',
#         'thumbnailImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/be584c7c7f547b8cbac318617f646680541f88071bc71db73cd461eb3ea6326e_1.png'},
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/be584c7c7f547b8cbac318617f646680541f88071bc71db73cd461eb3ea6326e_0.png'},
#         'id': 'Q29vcFN0YWdlLTE='},
#        '__isCoopSetting': 'CoopNormalSetting',
#        'weapons': [{'__splatoon3ink_id': 'bc57d58a39020d81',
#          'name': 'Splash-o-matic',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/weapon_illust/25e98eaba1e17308db191b740d9b89e6a977bfcd37c8dc1d65883731c0c72609_0.png'}},
#         {'__splatoon3ink_id': '09f425cd12f255dd',
#          'name': 'Glooga Dualies',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/weapon_illust/802d3d501738c620b4f709203ccad343490bd3340b2fda21eb38a362320dc6ed_0.png'}},
#         {'__splatoon3ink_id': '544a9b3e9bff7ecd',
#          'name': 'Dread Wringer',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/weapon_illust/1cf241ee28b282db23d25f1cce3d586151b9b67f4ba20cf5e2e74c82e988c352_0.png'}},
#         {'__splatoon3ink_id': '8e342dbd807d8d46',
#          'name': 'Tri-Stringer',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/weapon_illust/676d9f49276f171a93ac06646c0fbdfbeb8c3d0284a057aee306404a6034ffef_0.png'}}]},
#       '__splatoon3ink_king_salmonid_guess': 'Cohozuna'},
#      {'startTime': '2023-10-22T08:00:00Z',
#       'endTime': '2023-10-24T00:00:00Z',
#       'setting': {'__typename': 'CoopNormalSetting',
#        'coopStage': {'name': 'Sockeye Station',
#         'thumbnailImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/3418d2d89ef84288c78915b9acb63b4ad48df7bfcb48c27d6597920787e147ec_1.png'},
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/3418d2d89ef84288c78915b9acb63b4ad48df7bfcb48c27d6597920787e147ec_0.png'},
#         'id': 'Q29vcFN0YWdlLTI='},
#        '__isCoopSetting': 'CoopNormalSetting',
#        'weapons': [{'__splatoon3ink_id': '97976ade5f6d082d',
#          'name': 'Aerospray MG',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/weapon_illust/5ec00bcf96c7a3f731d7a2e67f60f802f33d22f07177b94d5905f471b08b629f_0.png'}},
#         {'__splatoon3ink_id': '0811ac580dabb9bd',
#          'name': 'Blaster',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/weapon_illust/29ccca01285a04f42dc15911f3cd1ee940f9ca0e94c75ba07378828afb3165c0_0.png'}},
#         {'__splatoon3ink_id': '6113b4a2c34d5bff',
#          'name': 'Splat Brella',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/weapon_illust/15d101d0d11acbb8159e2701282879f2617d90c8573fd2f2239807721ff54ca4_0.png'}},
#         {'__splatoon3ink_id': 'd666414e2d626aa5',
#          'name': 'Snipewriter 5H',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/weapon_illust/082489b182fbbabddde40831dac5867d6acc4778b6a38d8f5c8d445455d638eb_0.png'}}]},
#       '__splatoon3ink_king_salmonid_guess': 'Horrorboros'},
#      {'startTime': '2023-10-24T00:00:00Z',
#       'endTime': '2023-10-25T16:00:00Z',
#       'setting': {'__typename': 'CoopNormalSetting',
#        'coopStage': {'name': "Marooner's Bay",
#         'thumbnailImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/1a29476c1ab5fdbc813e2df99cd290ce56dfe29755b97f671a7250e5f77f4961_1.png'},
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/1a29476c1ab5fdbc813e2df99cd290ce56dfe29755b97f671a7250e5f77f4961_0.png'},
#         'id': 'Q29vcFN0YWdlLTY='},
#        '__isCoopSetting': 'CoopNormalSetting',
#        'weapons': [{'__splatoon3ink_id': '5cb99591156af714',
#          'name': 'Inkbrush',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/weapon_illust/260428edbf919f5c9e8c8517516d6a7a8133cf7348d216768ab4fb9434053f08_0.png'}},
#         {'__splatoon3ink_id': 'a36afedc0e51535e',
#          'name': 'Splatana Stamper',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/weapon_illust/ddd2a4258a70cdaf8a1dbc0ded024db497445d71f950fe7645fa8c69a178a082_0.png'}},
#         {'__splatoon3ink_id': '7b91a5e2edac50a9',
#          'name': 'Heavy Edit Splatling',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/weapon_illust/7f0192b8786a6fa7d5ed993022b1667de2fd90dadd8d34a3a7dff9578d34fa0a_0.png'}},
#         {'__splatoon3ink_id': 'd1d178c4f8590045',
#          'name': 'Rapid Blaster Pro',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/weapon_illust/954a5ea059f841fa5f1cd2596bb32f23b3d3b03fc3fa7972077bdbafe6051215_0.png'}}]},
#       '__splatoon3ink_king_salmonid_guess': 'Cohozuna'},
#      {'startTime': '2023-10-25T16:00:00Z',
#       'endTime': '2023-10-27T08:00:00Z',
#       'setting': {'__typename': 'CoopNormalSetting',
#        'coopStage': {'name': 'Salmonid Smokeyard',
#         'thumbnailImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/low_resolution/630d89698e3e260ef12cb2a32e1cb2c4c83c0e58fc882762da1fa2cea19a5260_1.png'},
#         'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/630d89698e3e260ef12cb2a32e1cb2c4c83c0e58fc882762da1fa2cea19a5260_0.png'},
#         'id': 'Q29vcFN0YWdlLTQ='},
#        '__isCoopSetting': 'CoopNormalSetting',
#        'weapons': [{'__splatoon3ink_id': '13451fa24f36cc4e',
#          'name': 'Squeezer',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/weapon_illust/db9f2ff8fab9f74c05c7589d43f132eacbff94154dcc20e09c864fced36d4d95_0.png'}},
#         {'__splatoon3ink_id': 'b4abca58bf916e93',
#          'name': 'Big Swig Roller',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/weapon_illust/137559b59547c853e04c6cc8239cff648d2f6b297edb15d45504fae91dfc9765_0.png'}},
#         {'__splatoon3ink_id': '48500e4854b4d769',
#          'name': 'Bloblobber',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/weapon_illust/0199e455872acba1ab8ef0040eca7f41afca48c1f9ad2c5d274323d6dbc49133_0.png'}},
#         {'__splatoon3ink_id': 'b29b38c98d5d0048',
#          'name': 'Jet Squelcher',
#          'image': {'url': 'https://splatoon3.ink/assets/splatnet/v2/weapon_illust/035920eb9428955c25aecb8a56c2b1b58f3e322af3657d921db1778de4b80c59_0.png'}}]},
#       '__splatoon3ink_king_salmonid_guess': 'Horrorboros'}]},
#    'bigRunSchedules': {'nodes': []},
#    'teamContestSchedules': {'nodes': []}},
#   'currentFest': None,
#   'currentPlayer': {'userIcon': {'url': 'https://cdn-image-e0d67c509fb203858ebcb2fe3f88c2aa.baas.nintendo.com/1/2066ebe78273022a'}},
#   'vsStages': {'nodes': [{'vsStageId': 1,
#      'originalImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/35f9ca08ccc2bf759774ab2cb886567c117b9287875ca92fb590c1294ddcdc1e_0.png'},
#      'name': 'Scorch Gorge',
#      'stats': None,
#      'id': 'VnNTdGFnZS0x'},
#     {'vsStageId': 2,
#      'originalImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/898e1ae6c737a9d44552c7c81f9b710676492681525c514eadc68a6780aa52af_0.png'},
#      'name': 'Eeltail Alley',
#      'stats': None,
#      'id': 'VnNTdGFnZS0y'},
#     {'vsStageId': 3,
#      'originalImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/8dc2f16d39c630bab40cead5b2485ca3559e829d0d3de0c2232c7a62fefb5fa9_0.png'},
#      'name': 'Hagglefish Market',
#      'stats': None,
#      'id': 'VnNTdGFnZS0z'},
#     {'vsStageId': 4,
#      'originalImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/9b1c17b2075479d0397d2fb96efbc6fa3a28900712920e5fe1e9dfc59c6abc5c_0.png'},
#      'name': 'Undertow Spillway',
#      'stats': None,
#      'id': 'VnNTdGFnZS00'},
#     {'vsStageId': 5,
#      'originalImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/f14c2a64e49d243679fc0884af91e1a07dc65600f9b90aefe92d7790dcffb191_0.png'},
#      'name': "Um'ami Ruins",
#      'stats': None,
#      'id': 'VnNTdGFnZS01'},
#     {'vsStageId': 6,
#      'originalImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/de1f212e9ff0648f36cd3b8e0917ef36b3bd51445159297dcb948f34a09f2f05_0.png'},
#      'name': 'Mincemeat Metalworks',
#      'stats': None,
#      'id': 'VnNTdGFnZS02'},
#     {'vsStageId': 7,
#      'originalImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/cd84d711b47a424334569ac20f33f8e0ab6a652dc07854dcd36508a0081e9034_0.png'},
#      'name': 'Brinewater Springs',
#      'stats': None,
#      'id': 'VnNTdGFnZS03'},
#     {'vsStageId': 8,
#      'originalImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/f70e9f5af477a39ccfab631bfb81c9e2cedb4cd0947fe260847c214a6d23695f_0.png'},
#      'name': 'Barnacle & Dime',
#      'stats': None,
#      'id': 'VnNTdGFnZS04'},
#     {'vsStageId': 9,
#      'originalImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/488017f3ce712fca9fb37d61fe306343054449bb2d2bb1751d95f54a98564cae_0.png'},
#      'name': 'Flounder Heights',
#      'stats': None,
#      'id': 'VnNTdGFnZS05'},
#     {'vsStageId': 10,
#      'originalImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/1db8ab338b64b464df50e7f9e270e59423ff8caac6f09679a24f1b7acf3a82f3_0.png'},
#      'name': 'Hammerhead Bridge',
#      'stats': None,
#      'id': 'VnNTdGFnZS0xMA=='},
#     {'vsStageId': 11,
#      'originalImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/b9d8cfa186d197a27e075600a107c99d9e21646d116730f0843e0fff0aaba7dd_0.png'},
#      'name': "Museum d'Alfonsino",
#      'stats': None,
#      'id': 'VnNTdGFnZS0xMQ=='},
#     {'vsStageId': 12,
#      'originalImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/8273118c1ffe1bf6fe031c7d8c9795dab52632c9b76e8e9f01f644ac5ae0ccc0_0.png'},
#      'name': 'Mahi-Mahi Resort',
#      'stats': None,
#      'id': 'VnNTdGFnZS0xMg=='},
#     {'vsStageId': 13,
#      'originalImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/40aba8b36a9439e2d670fde5b3478819ea8a94f9e503b9d783248a5716786f35_0.png'},
#      'name': 'Inkblot Art Academy',
#      'stats': None,
#      'id': 'VnNTdGFnZS0xMw=='},
#     {'vsStageId': 14,
#      'originalImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/48684c69d5c5a4ffaf16b712a4895545a8d01196115d514fc878ce99863bb3e9_0.png'},
#      'name': 'Sturgeon Shipyard',
#      'stats': None,
#      'id': 'VnNTdGFnZS0xNA=='},
#     {'vsStageId': 15,
#      'originalImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/a8ba96c3dbd015b7bc6ea4fa067245c4e9aee62b6696cb41e02d35139dd21fe7_0.png'},
#      'name': 'MakoMart',
#      'stats': None,
#      'id': 'VnNTdGFnZS0xNQ=='},
#     {'vsStageId': 16,
#      'originalImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/61ea801fa4ed32360dcaf83986222ded46a72dbf56194acc6d0cf4659a92ba85_0.png'},
#      'name': 'Wahoo World',
#      'stats': None,
#      'id': 'VnNTdGFnZS0xNg=='},
#     {'vsStageId': 17,
#      'originalImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/7b3cf118bd9f45d141cd6db0ee75b06e697fa83945c7fe1e6f8483de6a591f5f_0.png'},
#      'name': 'Humpback Pump Track',
#      'stats': None,
#      'id': 'VnNTdGFnZS0xNw=='},
#     {'vsStageId': 18,
#      'originalImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/0b7fd997781e03eb9d5bf1875ed070f698afc654f4fe929452c65aa26c0a35fd_0.png'},
#      'name': 'Manta Maria',
#      'stats': None,
#      'id': 'VnNTdGFnZS0xOA=='},
#     {'vsStageId': 19,
#      'originalImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/4e0e9e2046aff1d635e23946d9f0a461486d2aab349079e551037e426ac82c7a_0.png'},
#      'name': 'Crableg Capital',
#      'stats': None,
#      'id': 'VnNTdGFnZS0xOQ=='},
#     {'vsStageId': 20,
#      'originalImage': {'url': 'https://splatoon3.ink/assets/splatnet/v2/stage_img/icon/high_resolution/b65a70eedf129848b9d2b492bb68712abf91a5cbda13131848947fb04c51d665_0.png'},
#      'name': 'Shipshape Cargo Co.',
#      'stats': None,
#      'id': 'VnNTdGFnZS0yMA=='}]}}}

# %%
for entry in data["data"]["bankaraSchedules"]["nodes"]:
    start_time.append(entry["startTime"])
    #end_time.append(entry["endTime"])
    for subentry in entry["bankaraMatchSettings"]: #["bankaraMatchSettings"]:
        if subentry["bankaraMode"] == "OPEN":
            print(subentry["vsRule"]["name"])
            mode_list.append(subentry["vsRule"]["name"])
            for trientry in subentry["vsStages"]:
                map_list.append(trientry["name"])
# Out:
# Clam Blitz
# Rainmaker
# Splat Zones
# Rainmaker
# Tower Control
# Splat Zones
# Clam Blitz
# Rainmaker
# Tower Control
# Splat Zones
# Clam Blitz
# Rainmaker
# Tower Control

# %%
mode_list
# Out:
# ['Clam Blitz',
#  'Rainmaker',
#  'Splat Zones',
#  'Rainmaker',
#  'Tower Control',
#  'Splat Zones',
#  'Clam Blitz',
#  'Rainmaker',
#  'Tower Control',
#  'Splat Zones',
#  'Clam Blitz',
#  'Rainmaker',
#  'Tower Control']

# %%
map_1 = []
map_2 = []
for i in range(len(map_list)):
    if i%2==0:
        map_1.append(map_list[i])
    else:
        map_2.append(map_list[i])

# %%
#pairs = []
#for i in range(0, len(map_list), 2):
#    pairs.append((map_list[i], map_list[i+1]))

#pairs
    
#L = [1, 2, 3, 4, 5, 6]
#L2 = []

#for i in range(0, len(L), 2):
# L2.append((L[i], L[i+1]))

# %%
len(mode_list)
# Out:
# 13

# %%
import pandas as pd
#full_data = {"title" : title_list, "rank_no" : rank_list,"price":price_list,'appid':appid_list,'bundleid':bundleid_list,'crtrids':crtrids_list}
full_data = {"startTime": start_time[:13], "mode":mode_list, "map1": map_1, "map2": map_2} #"endTime": end_time[:12]
full_df=pd.DataFrame(full_data)
full_df.to_csv("splatoon_maps.csv")

# %%
splatoon = pd.read_csv("splatoon_maps.csv")
splatoon = splatoon.drop(columns=["Unnamed: 0"])
splatoon
# Out:
#                startTime           mode                  map1  \
# 0   2023-10-19T18:00:00Z     Clam Blitz   Humpback Pump Track
# 1   2023-10-19T20:00:00Z      Rainmaker      Mahi-Mahi Resort
# 2   2023-10-19T22:00:00Z    Splat Zones     Hammerhead Bridge
# 3   2023-10-20T00:00:00Z      Rainmaker       Barnacle & Dime
# 4   2023-10-20T02:00:00Z  Tower Control  Mincemeat Metalworks
# 5   2023-10-20T04:00:00Z    Splat Zones     Undertow Spillway
# 6   2023-10-20T06:00:00Z     Clam Blitz     Hagglefish Market
# 7   2023-10-20T08:00:00Z      Rainmaker         Eeltail Alley
# 8   2023-10-20T10:00:00Z  Tower Control           Manta Maria
# 9   2023-10-20T12:00:00Z    Splat Zones     Undertow Spillway
# 10  2023-10-20T14:00:00Z     Clam Blitz  Mincemeat Metalworks
# 11  2023-10-20T16:00:00Z      Rainmaker   Inkblot Art Academy
# 12  2023-10-20T18:00:00Z  Tower Control      Flounder Heights
#
#                    map2
# 0           Manta Maria
# 1           Wahoo World
# 2              MakoMart
# 3    Museum d'Alfonsino
# 4      Flounder Heights
# 5          Um'ami Ruins
# 6    Brinewater Springs
# 7   Shipshape Cargo Co.
# 8       Crableg Capital
# 9     Sturgeon Shipyard
# 10  Humpback Pump Track
# 11          Wahoo World
# 12             MakoMart

# %%
from datetime import datetime
import pytz

#datetime.fromisoformat('2020-01-06T00:00:00.000Z'[:-1] + '+00:00')
#datetime.datetime(2020, 1, 6, 0, 0, tzinfo=datetime.timezone.utc)

first = splatoon["startTime"].values[0]

values = []
for i in splatoon["startTime"].values:
    d = datetime.fromisoformat(i[:-1]) #.astimezone(timezone.utc)
    
    utc = pytz.utc.localize(d)
    pst = utc.astimezone(pytz.timezone("America/Los_Angeles"))
    values.append(pst.strftime("%H:%M"))

values
# Out:
# ['11:00',
#  '13:00',
#  '15:00',
#  '17:00',
#  '19:00',
#  '21:00',
#  '23:00',
#  '01:00',
#  '03:00',
#  '05:00',
#  '07:00',
#  '09:00',
#  '11:00']

# %%
splatoon["time"] = values
splatoon = splatoon[["time", "mode", "map1", "map2"]]

# %%
splatoon.to_csv("rotations.csv") #save

# %% [markdown]
# ### All Map Modes:

# %%
splatoon
# Out:
#      time           mode                  map1                 map2
# 0   11:00     Clam Blitz   Humpback Pump Track          Manta Maria
# 1   13:00      Rainmaker      Mahi-Mahi Resort          Wahoo World
# 2   15:00    Splat Zones     Hammerhead Bridge             MakoMart
# 3   17:00      Rainmaker       Barnacle & Dime   Museum d'Alfonsino
# 4   19:00  Tower Control  Mincemeat Metalworks     Flounder Heights
# 5   21:00    Splat Zones     Undertow Spillway         Um'ami Ruins
# 6   23:00     Clam Blitz     Hagglefish Market   Brinewater Springs
# 7   01:00      Rainmaker         Eeltail Alley  Shipshape Cargo Co.
# 8   03:00  Tower Control           Manta Maria      Crableg Capital
# 9   05:00    Splat Zones     Undertow Spillway    Sturgeon Shipyard
# 10  07:00     Clam Blitz  Mincemeat Metalworks  Humpback Pump Track
# 11  09:00      Rainmaker   Inkblot Art Academy          Wahoo World
# 12  11:00  Tower Control      Flounder Heights             MakoMart

# %% [markdown]
# ### Now, pick 1-2 maps you want to know the schedule of for each mode (i.e. map preferences)

# %%
zones = splatoon[splatoon["mode"]=="Splat Zones"]
maps_zones_1 = zones[(zones["map1"]=="Shipshape Cargo Co.") | (zones["map2"]=="Hagglefish Mrket")]
maps_zones_2 = zones[(zones["map2"]=="Shipshape Cargo Co.") | (zones["map1"]=="Hagglefish Mrket")]

tower = splatoon[splatoon["mode"]=="Tower Control"]
maps_tower_1 = tower[(tower["map1"]=="Sturgeon Shipyard") | (tower["map2"]=="Inkblot Art Academy")]
maps_tower_2 = tower[(tower["map2"]=="Sturgeon Shipyard") | (tower["map1"]=="Inkblot Art Academy")]

rain = splatoon[splatoon["mode"]=="Rainmaker"]
maps_rain_1 = rain[(rain["map1"]=="Eeltail Alley") | (rain["map2"]=="Humpback Pump Track")]
maps_rain_2 = rain[(rain["map2"]=="Eeltail Alley") | (rain["map1"]=="Humpback Pump Track")]

clams = splatoon[splatoon["mode"]=="Clam Blitz"]
maps_clams_1 = clams[(clams["map1"]=="Scorch Gorge") | (clams["map2"]=="Scorch Gorge")]
maps_clams_2 = None
#clams[(clams["map2"]=="Museum d'Alfonsino") | (clams["map1"]=="Scorch Gorge")]


all_modes = pd.concat([maps_zones_1, maps_zones_2, maps_tower_1, maps_tower_2, maps_rain_1, maps_rain_2, 
                       maps_clams_1, maps_clams_2], join="inner")

#all_modes = pd.concat([maps_zones_1, maps_zones_2, maps_tower_1, maps_tower_2, maps_rain_1, maps_rain_2, 
#                       maps_clams_1, maps_clams_2], join="inner")

# %% [markdown]
# ## Result Table:

# %%
all_modes.sort_values(by=["time"]).reset_index().drop(columns=["index"])
# Out:
#     time       mode           map1                 map2
# 0  01:00  Rainmaker  Eeltail Alley  Shipshape Cargo Co.

# %% [markdown]
# ### **Finding:** There are usually 1-4 rotations that match one's map preferences for all modes.
